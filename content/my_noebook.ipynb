# %% [markdown]
# # My JupyterLite Notebook
# Testing NumPy and scikit-learn.

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

X = np.array([[1],[2],[3],[4]])
y = np.array([2,4,6,8])

model = LinearRegression()
model.fit(X,y)
model.predict([[5]])
